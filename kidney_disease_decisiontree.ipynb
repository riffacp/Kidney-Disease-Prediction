# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\HP\Desktop\int\kidney\kidney_disease.csv')
data
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...   pcv      wc   rc  htn   dm  cad  appet   pe  ane  \
# 0    notpresent  ...  44.0  7800.0  5.2  yes  yes   no   good   no   no
# 1    notpresent  ...  38.0  6000.0  NaN   no   no   no   good   no   no
# 2    notpresent  ...  31.0  7500.0  NaN   no  yes   no   poor   no  yes
# 3    notpresent  ...  32.0  6700.0  3.9  yes   no   no   poor  yes  yes
# 4    notpresent  ...  35.0  7300.0  4.6   no   no   no   good   no   no
# ..          ...  ...   ...     ...  ...  ...  ...  ...    ...  ...  ...
# 395  notpresent  ...  47.0  6700.0  4.9   no   no   no   good   no   no
# 396  notpresent  ...  54.0  7800.0  6.2   no   no   no   good   no   no
# 397  notpresent  ...  49.0  6600.0  5.4   no   no   no   good   no   no
# 398  notpresent  ...  51.0  7200.0  5.9   no   no   no   good   no   no
# 399  notpresent  ...  53.0  6800.0  6.1   no   no   no   good   no   no
#
#     classification
# 0              ckd
# 1              ckd
# 2              ckd
# 3              ckd
# 4              ckd
# ..             ...
# 395         notckd
# 396         notckd
# 397         notckd
# 398         notckd
# 399         notckd
#
# [400 rows x 26 columns]

# %%
data.shape
# Out:
# (400, 26)

# %%
data.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo  \
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# std     79.281714   50.503006    5.741126   10.408752    3.193904    2.912587
# min     22.000000    1.500000    0.400000    4.500000    2.500000    3.100000
# 25%     99.000000   27.000000    0.900000  135.000000    3.800000   10.300000
# 50%    121.000000   42.000000    1.300000  138.000000    4.400000   12.650000
# 75%    163.000000   66.000000    2.800000  142.000000    4.900000   15.000000
# max    490.000000  391.000000   76.000000  163.000000   47.000000   17.800000
#
#               pcv            wc
# count  330.000000    295.000000
# mean    38.933333   8396.081356
# std      9.020162   2944.517219
# min      9.000000   2200.000000
# 25%     32.000000   6500.000000
# 50%     40.000000   8000.000000
# 75%     45.000000   9800.000000
# max     55.000000  26400.000000

# %%
data.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
data['pcv']=data['pcv'].fillna(35)
data['wc']=data['wc'].fillna(7200)

# %%
data['pcv']=data['pcv'].replace({'\t?':35})

# %%
data['wc']=data['wc'].replace({'\t?':7500})

# %%
data.drop(columns=['rc'], inplace=True)
data
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  hemo   pcv      wc  htn   dm  cad  appet   pe  ane  \
# 0    notpresent  ...  15.4  44.0  7800.0  yes  yes   no   good   no   no
# 1    notpresent  ...  11.3  38.0  6000.0   no   no   no   good   no   no
# 2    notpresent  ...   9.6  31.0  7500.0   no  yes   no   poor   no  yes
# 3    notpresent  ...  11.2  32.0  6700.0  yes   no   no   poor  yes  yes
# 4    notpresent  ...  11.6  35.0  7300.0   no   no   no   good   no   no
# ..          ...  ...   ...   ...     ...  ...  ...  ...    ...  ...  ...
# 395  notpresent  ...  15.7  47.0  6700.0   no   no   no   good   no   no
# 396  notpresent  ...  16.5  54.0  7800.0   no   no   no   good   no   no
# 397  notpresent  ...  15.8  49.0  6600.0   no   no   no   good   no   no
# 398  notpresent  ...  14.2  51.0  7200.0   no   no   no   good   no   no
# 399  notpresent  ...  15.8  53.0  6800.0   no   no   no   good   no   no
#
#     classification
# 0              ckd
# 1              ckd
# 2              ckd
# 3              ckd
# 4              ckd
# ..             ...
# 395         notckd
# 396         notckd
# 397         notckd
# 398         notckd
# 399         notckd
#
# [400 rows x 25 columns]

# %%
data.drop(columns=['id'], inplace=True)
data.head()
# Out:
#     age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr  ...  hemo   pcv      wc  htn   dm  cad  appet   pe  ane  \
# 0  121.0  ...  15.4  44.0  7800.0  yes  yes   no   good   no   no
# 1    NaN  ...  11.3  38.0  6000.0   no   no   no   good   no   no
# 2  423.0  ...   9.6  31.0  7500.0   no  yes   no   poor   no  yes
# 3  117.0  ...  11.2  32.0  6700.0  yes   no   no   poor  yes  yes
# 4  106.0  ...  11.6  35.0  7300.0   no   no   no   good   no   no
#
#   classification
# 0            ckd
# 1            ckd
# 2            ckd
# 3            ckd
# 4            ckd
#
# [5 rows x 24 columns]

# %%
data['rbc']=data['rbc'].fillna(method='ffill')
data['pc']=data['pc'].fillna(method='ffill')
data['pcc']=data['pcc'].fillna(method='ffill')
data['ba']=data['ba'].fillna(method='ffill')
data['htn']=data['htn'].fillna(method='ffill')
data['dm']=data['dm'].fillna(method='ffill')
data['cad']=data['cad'].fillna(method='ffill')
data['appet']=data['appet'].fillna(method='ffill')
data['pe']=data['pe'].fillna(method='ffill')
data['ane']=data['ane'].fillna(method='ffill')
data['classification']=data['classification'].fillna(method='ffill')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5108\3661458943.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['rbc']=data['rbc'].fillna(method='ffill')
# C:\Users\HP\AppData\Local\Temp\ipykernel_5108\3661458943.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['pc']=data['pc'].fillna(method='ffill')
# C:\Users\HP\AppData\Local\Temp\ipykernel_5108\3661458943.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['pcc']=data['pcc'].fillna(method='ffill')
# C:\Users\HP\AppData\Local\Temp\ipykernel_5108\3661458943.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['ba']=data['ba'].fillna(method='ffill')
# C:\Users\HP\AppData\Local\Temp\ipykernel_5108\3661458943.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['htn']=data['htn'].fillna(method='ffill')
# C:\Users\HP\AppData\Local\Temp\ipykernel_5108\3661458943.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['dm']=data['dm'].fillna(method='ffill')
# C:\Users\HP\AppData\Local\Temp\ipykernel_5108\3661458943.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['cad']=data['cad'].fillna(method='ffill')
# C:\Users\HP\AppData\Local\Temp\ipykernel_5108\3661458943.py:8: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['appet']=data['appet'].fillna(method='ffill')
# C:\Users\HP\AppData\Local\Temp\ipykernel_5108\3661458943.py:9: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['pe']=data['pe'].fillna(method='ffill')
# C:\Users\HP\AppData\Local\Temp\ipykernel_5108\3661458943.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['ane']=data['ane'].fillna(method='ffill')
# C:\Users\HP\AppData\Local\Temp\ipykernel_5108\3661458943.py:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['classification']=data['classification'].fillna(method='ffill')

# %%
data['age']=data['age'].fillna(data['age'].median())
data['bp']=data['bp'].fillna(data['bp'].median())
data['sg']=data['sg'].fillna(data['sg'].median())
data['al']=data['al'].fillna(data['al'].median())
data['su']=data['su'].fillna(data['su'].median())
data['bgr']=data['bgr'].fillna(data['bgr'].median())
data['bu']=data['bu'].fillna(data['bu'].median())
data['sc']=data['sc'].fillna(data['sc'].median())
data['sod']=data['sod'].fillna(data['sod'].median())
data['pot']=data['pot'].fillna(data['pot'].median())
data['hemo']=data['hemo'].fillna(data['hemo'].median())
data['pcv']=data['pcv'].fillna(data['pcv'].median())

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
data['rbc']=l.fit_transform(data['rbc'])
data['pc']=l.fit_transform(data['pc'])
data['pcc']=l.fit_transform(data['pcc'])
data['ba']=l.fit_transform(data['ba'])
data['htn']=l.fit_transform(data['htn'])
data['dm']=l.fit_transform(data['dm'])
data['cad']=l.fit_transform(data['cad'])
data['appet']=l.fit_transform(data['appet'])
data['pe']=l.fit_transform(data['pe'])
data['ane']=l.fit_transform(data['ane'])
data['classification']=l.fit_transform(data['classification'])
data.head()
# Out:
#     age    bp     sg   al   su  rbc  pc  pcc  ba    bgr  ...  hemo   pcv  \
# 0  48.0  80.0  1.020  1.0  0.0    2   1    0   0  121.0  ...  15.4  44.0
# 1   7.0  50.0  1.020  4.0  0.0    2   1    0   0  121.0  ...  11.3  38.0
# 2  62.0  80.0  1.010  2.0  3.0    1   1    0   0  423.0  ...   9.6  31.0
# 3  48.0  70.0  1.005  4.0  0.0    1   0    1   0  117.0  ...  11.2  32.0
# 4  51.0  80.0  1.010  2.0  0.0    1   1    0   0  106.0  ...  11.6  35.0
#
#        wc  htn  dm  cad  appet  pe  ane  classification
# 0  7800.0    1   4    1      0   0    0               0
# 1  6000.0    0   3    1      0   0    0               0
# 2  7500.0    0   4    1      1   0    1               0
# 3  6700.0    1   3    1      1   1    1               0
# 4  7300.0    0   3    1      0   0    0               0
#
# [5 rows x 24 columns]

# %%
x=data.drop(['classification'],axis=1)
y=data['classification']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((320, 23), (80, 23), (320,), (80,))

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
model.predict(xtest)
# Out:
# array([2, 2, 0, 0, 0, 2, 0, 0, 2, 2, 2, 0, 0, 0, 2, 0, 2, 2, 2, 0, 0, 0,
#        2, 2, 2, 2, 0, 0, 0, 2, 0, 0, 2, 2, 2, 0, 0, 0, 2, 2, 0, 0, 0, 2,
#        0, 0, 0, 0, 0, 0, 0, 0, 2, 2, 2, 0, 2, 0, 0, 0, 0, 0, 2, 0, 0, 2,
#        0, 0, 0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 0, 2])

# %%
model.score(xtest,ytest)
# Out:
# 0.9625

# %%
v=model.predict([[48,89,1.000,3.0,2,0,1,0,0,115.000000,30.0,111.000000,4.633420,11.6,32,7300,1,3,1,0,1,0,0]])
if v==0:
    print('yes you have diabetics')
else:
    print('no you dont have diabetics')
# Out:
# yes you have diabetics
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
